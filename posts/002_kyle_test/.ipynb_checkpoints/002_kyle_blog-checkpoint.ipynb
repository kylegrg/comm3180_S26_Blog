# %% [raw]
# ---
# title: "Kyle's Test Post"
# description: "Figuring out how to do this!"
# author: "Kyle Grgecic"
# date: "1/23/2025"
# categories:
#   - Tutorials
#   - Figuring it out
# ---

# %% [markdown]
# # Test!
#
# This is my first attempt at making a blog.
