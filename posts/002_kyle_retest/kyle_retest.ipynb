# %% [raw]
# ---
# title: "Kyle Grgecic's Data Blog test post"
# description: "Example post"
# author: "Kyle Grgecic"
# date: "1/23/26"
# categories:
#   - visualization
#   - data stories
# ---

# %% [markdown]
# ## Testing to see if I get another error!
#
# - Let me know if this looks okay!
# - Hoping this is enough
